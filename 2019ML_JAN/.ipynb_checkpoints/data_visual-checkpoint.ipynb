# %%
import matplotlib.pyplot   as  plt

# %%
x=[4,7,9,12]

y=[6,9,6,10]
# Out:
#   File "<ipython-input-6-11e8a301bc41>", line 2
#     x1=[,12,8,89]
#         ^
# SyntaxError: invalid syntax

# %%
plt.plot(x,y)  #  to plot graph in maths way
plt.show()   #  to show the same
