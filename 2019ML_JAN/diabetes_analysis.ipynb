# %%
import pandas as pd
import  seaborn  as  sb

# %%
#  reading csv file and converting into data frames
df=pd.read_csv('diabetes.csv')
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#  creating  training and testing datasets 
label=df['Outcome']

features=df[df.columns[:-1]]

# %%
sb.countplot(df['Outcome'])

# %%
df.info()  #  to check all info about  data with null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.hist(figsize=(14,14))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb86289a978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb862499908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb8623c4e80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb862740438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb8627569b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb8626eef28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb86270c4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb8626a4a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb8626bcfd0>]],
#       dtype=object)

# %%
df.groupby('Outcome').size()
#  splling
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
#  importing  kNN
from  sklearn.neighbors  import KNeighborsClassifier
knn_clf=KNeighborsClassifier(n_neighbors=5)
trained=knn_clf.fit(features,label)
